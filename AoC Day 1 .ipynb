#  '1982',
#  '1541',
#  '1106',
#  '1248',
#  '1346',
#  '1782',
#  '1142',
#  '1849',
#  '1798',
#  '1362',
#  '1379',
#  '1886',
#  '1265',
# ...

# %%
#list comprehension then resulting iterator into a list
expenses = [int(string) for string in split_input]
expenses
# Out:
# [1934,
#  1702,
#  1571,
#  1737,
#  1977,
#  1531,
#  1428,
#  1695,
#  1794,
#  1101,
#  13,
#  1164,
#  1235,
#  1289,
#  1736,
#  1814,
#  1363,
#  1147,
#  1111,
#  1431,
#  1765,
#  1515,
#  1184,
#  1036,
#  1803,
#  1791,
#  1638,
#  1809,
#  1283,
#  1980,
#  1854,
#  1878,
#  1574,
#  1352,
#  1151,
#  730,
#  1581,
#  1990,
#  1919,
#  2003,
#  1538,
#  1663,
#  1735,
#  1772,
#  1830,
#  1152,
#  1022,
#  1774,
#  1544,
#  1551,
#  1835,
#  1383,
#  1614,
#  1396,
#  1715,
#  1530,
#  295,
#  1208,
#  1978,
#  1104,
#  1691,
#  1176,
#  1183,
#  1909,
#  1192,
#  1535,
#  1924,
#  1268,
#  1969,
#  1954,
#  1760,
#  1077,
#  1734,
#  1371,
#  1676,
#  1933,
#  1400,
#  1928,
#  1982,
#  1541,
#  1106,
#  1248,
#  1346,
#  1782,
#  1142,
#  1849,
#  1798,
#  1362,
#  1379,
#  1886,
#  1265,
#  1226,
#  1751,
#  1575,
#  1027,
#  1710,
#  1601,
#  1205,
#  1922,
#  1452,
#  1206,
#  1263,
#  2000,
#  1957,
#  1951,
#  1834,
#  1533,
#  1149,
#  1245,
#  1564,
#  1182,
# ...

# %%
#to solve, we need to generate all possible combinations using the itertools module
from itertools import *

# %%
all_expenses_pairs = list(combinations(expenses, 2))
len(all_expenses_pairs)
# Out:
# 19900

# %%
#using filter() fctn to extract a list of defined pairs
def sums_to_2020(values):
    return sum(values) == 2020

result = list(filter(sums_to_2020, all_expenses_pairs))
result
# Out:
# [(1504, 516)]

# %%
1504 * 516
# Out:
# 776064

# %% [markdown]
# # Day 1 - Part 2
# Need to find three numbers in the string that meet the same criteria
# What is the product of the three entries that sum to 2020?

# %%
#using itertools.combinations() for three lines of code 
all_expenses_triplets = list(combinations(expenses, 3))

# %%
result2 = list(filter(sums_to_2020, all_expenses_triplets))
result2
# Out:
# [(13, 317, 1690)]

# %%
13 * 317 * 1690
# Out:
# 6964490

# %% [markdown]
# 🥳
